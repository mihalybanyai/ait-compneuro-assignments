# %% [markdown]
# # Introductory Tutorial
#
# The first main goal of this notebook is to get everyone up to speed in terms of running python code in jupyter notebooks, and our tutorials in particular. The second goal is to illustrate some basic concepts from probability theory.
#
# Prepared by Mihály Bányai, 2026. mihaly.s.banyai@gmail.com, https://visionlab-ceu.org/people/mihaly-banyai/
#
# Running the following box should install all packages that we'll need over the course of the semester. You can do this inside a dedicated virtual environment (venv, conda, etc.), in the global python environment of your computer, or even on google colabs. My notebooks are tested with the python kernel version 3.12.5, but they should work with other kernels not extremely distant from this in terms of version number (definitely use Python 3 though).

# %%
# !pip install numpy scipy matplotlib ipynb levenshtein daft-pgm ipympl
# Out:
# Requirement already satisfied: numpy in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (1.25.2)
# Requirement already satisfied: scipy in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (1.11.1)
# Requirement already satisfied: matplotlib in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (3.7.2)
# Collecting ipynb
#   Obtaining dependency information for ipynb from https://files.pythonhosted.org/packages/31/42/4c0bbb66390e3a68e04ebf134c8d074a00c18b5882293f8ace5f7497fbf0/ipynb-0.5.1-py3-none-any.whl.metadata
#   Downloading ipynb-0.5.1-py3-none-any.whl.metadata (303 bytes)
# Collecting levenshtein
#   Obtaining dependency information for levenshtein from https://files.pythonhosted.org/packages/0e/fd/42e28a86e2f04a2e064faa1eab7d81a35fb111212b508ce7e450f839943d/levenshtein-0.27.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading levenshtein-0.27.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (3.7 kB)
# Collecting daft-pgm
#   Obtaining dependency information for daft-pgm from https://files.pythonhosted.org/packages/6a/10/8177be1c256b10b5a7b22efad96d74568ab4f4cdac22056e742f5284a409/daft_pgm-0.1.4-py3-none-any.whl.metadata
#   Downloading daft_pgm-0.1.4-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: ipympl in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (0.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Collecting rapidfuzz<4.0.0,>=3.9.0 (from levenshtein)
#   Obtaining dependency information for rapidfuzz<4.0.0,>=3.9.0 from https://files.pythonhosted.org/packages/76/25/5b0a33ad3332ee1213068c66f7c14e9e221be90bab434f0cb4defa9d6660/rapidfuzz-3.14.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading rapidfuzz-3.14.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: ipython<9 in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from ipympl) (8.15.0)
# Requirement already satisfied: ipython-genutils in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: traitlets<6 in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from ipympl) (5.7.1)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from ipympl) (8.1.1)
# Requirement already satisfied: backcall in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from ipython<9->ipympl) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from ipython<9->ipympl) (0.1.6)
# Requirement already satisfied: pickleshare in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from ipython<9->ipympl) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from ipython<9->ipympl) (2.15.1)
# Requirement already satisfied: stack-data in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from ipython<9->ipympl) (4.8.0)
# Requirement already satisfied: appnope in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from ipython<9->ipympl) (0.1.2)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.1.4)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.9)
# Requirement already satisfied: six>=1.5 in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from pexpect>4.3->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython<9->ipympl) (0.2.5)
# Requirement already satisfied: executing in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from stack-data->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: asttokens in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from stack-data->ipython<9->ipympl) (2.0.5)
# Requirement already satisfied: pure-eval in /usr/local/anaconda3/envs/bbu311/lib/python3.11/site-packages (from stack-data->ipython<9->ipympl) (0.2.2)
# Downloading ipynb-0.5.1-py3-none-any.whl (6.9 kB)
# Downloading levenshtein-0.27.3-cp311-cp311-macosx_10_9_x86_64.whl (172 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.2/172.2 kB 2.6 MB/s eta 0:00:00a 0:00:01
# Downloading daft_pgm-0.1.4-py3-none-any.whl (13 kB)
# Downloading rapidfuzz-3.14.3-cp311-cp311-macosx_10_9_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 9.3 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: rapidfuzz, ipynb, levenshtein, daft-pgm
# Successfully installed daft-pgm-0.1.4 ipynb-0.5.1 levenshtein-0.27.3 rapidfuzz-3.14.3

# %% [markdown]
# The following box imports some basic packages.

# %%
import numpy as np  # for handling arrays
import scipy as sp  # scientific tools, e.g. probability distributions
import matplotlib.pyplot as plt  # plotting
import matplotlib as mpl  # some plotting-related functions need this separately
import daft  # to plot graphical Bayesian models nicely
#the following lets you zoom into and explore figures, may require you to restart the kernel:
# %matplotlib widget

# %% [markdown]
# We will look at posterior inference in a Bayesian generative model. The model has one observed variable, $k$, and one latent variable, $\lambda$. The following code plots a nice visual representation of the model using the daft language. You don't need to learn this, but it's useful for communicating modelling ideas.
#
# The $\alpha$ and $\theta$ parameters in the model indicate the parameters of the Gamma prior distribution for the latent $\lambda$ variable. These we consider fixed and given. The shading of the circle of $k$ indicates that we will receive observations for this variable. The unshaded circle of $\lambda$ indicates that this is a latent variable that we may infer using observations of a different variable ($k$ in this case) and the model itself. The plate around $k$ with the number $n$ indicates that we will receive $n$ observations of $k$ at the same time. $\lambda$ not being on the plate means that there will be a single posterior distribution over it calculated from all $n$ observations of $k$.
#
# The model will be completed by giving the formulas for the prior distribution and the likelihood function:
#
# $p(\lambda) = Gamma(\lambda; \alpha, \theta)$
#
# $p(k \mid \lambda) = Poisson(k; \lambda)$

# %%
mpl.rc("font", family="serif", size=14)
pgm = daft.PGM((4, 3), origin=(0.15, 0.15))
pgm.add_node(daft.Node("k", r"$k$", 0.65, 0.9, observed=True))
pgm.add_node(daft.Node("lambda", r"$\lambda$", 0.65, 1.8, observed=False))
pgm.add_node(daft.Node("alpha", r"$\alpha$", 0.65, 2.7, observed=False, plot_params={"ec": "none"}))
pgm.add_node(daft.Node("theta", r"$\theta$", 1.65, 2.7, observed=False, plot_params={"ec": "none"}))
pgm.add_plate(daft.Plate([0.15, 0.2, 1., 1.2],label=r"$n$"))
pgm.add_edge("lambda","k")
pgm.add_edge("alpha","lambda")
pgm.add_edge("theta","lambda")
pgm.render()
# Out:
# <Axes: >
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
# first we define the range over which we want to calculate distributions of the latent variable
# note that lambda is a keyword in Python (related to lambda calculus), so you can't have a variable named lambda, you can use lamb, lambda_, etc.
lambda_support = np.linspace(0, 20, 200)
alpha, theta = 20, -10
# what we do in the next line is called a list comprehension:
prior = np.array([sp.stats.gamma(alpha,theta).pdf(lamb) for lamb in lambda_support])
# it's equivalent to the following code:
# prior = np.zeros((len(lambda_support)))
# for lambda_index, lamb in enumerate(lambda_support):
#     prior[lambda_index] = sp.stats.gamma(alpha,theta).pdf(lamb)

plt.plot(lambda_support, prior, label="prior")

# we receive the observations and calculate the likelihood function
observations = [4]
# the following is a nested list compreshension:
likelihood = np.array([np.array([sp.stats.poisson(lamb).pmf(obs) for obs in observations]).prod() for lamb in lambda_support])
# it's equivalent to the following:
# likelihood = np.zeros((len(lambda_support)))
# for lambda_index, lamb in enumerate(lambda_support):
#     likelihoods_for_all_observations = np.zeros(len(observations))
#     for obs_index, obs in enumerate(observations):
#         likelihoods_for_all_observations[obs_index] = sp.stats.poisson(lamb).pmf(obs)
#     likelihood[lambda_index] = likelihoods_for_all_observations.prod()
    
plt.plot(lambda_support, likelihood, label="likelihood")

# we calculate the posterior using Bayes' theorem
unnorm_posterior = likelihood * prior
# doing the normalisation properly requires taking into account how densely we evaluate the functions
grid_step_size = (lambda_support[-1] - lambda_support[0]) / len(lambda_support)
posterior = unnorm_posterior / (unnorm_posterior.sum() * grid_step_size)
plt.plot(lambda_support, posterior, label="posterior")
plt.xlabel(r"$\lambda$")
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Code readability hints

## Casts - these are type conversion operators that don't do any interesting computation
x = [[5]]
np.array(x) # converts x into a numpy array
x.flatten() # converts a multiminsional numpy array into a one-dimensional one
x.item() # converts an array with a single element in it into a scalar
list(x) # converts x to a list

## for loops on enumerations
for element_index, element in enumerate(x):
    print("The %dth element of array x is %d" % (element_index, element)) 
# is equivalent to
for element_index in range(len(x)):
    print("The %dth element of array x is %d" % (element_index, x[element_index])) 

## list comprehensions
result = [element + 1 for element in x]
# is equivalent to
result = []
for element in x:
    result.append(element + 1)
